# %%
import os
import sys
import matplotlib.pyplot as plt
import pandas as pd
import numpy as num
import matplotlib as mpl
sys.path

# Read/Write Excel Files
Vastgoed = pd.read_excel('/Users/yanthemac/Downloads/Data/Vastgoed.xlsx')
Inflatie = pd.read_excel('/Users/yanthemac/Downloads/Data/Inflatie.xlsx')

# %%
# Inflatie
product = "Brood en granen"

inflatie_product = Inflatie.query(f'Product == "{product}"')[['Inflatie']]
inflatie_jaar = Inflatie.query(f'Product == "{product}"')[['Year']]
plt.title(f'{product} Inflatie')

plt.plot(inflatie_jaar, inflatie_product)

# %%
# City Renting Prices
# city = input("CITY: ")
city = "LEUVEN"
city2 = "ANTWERPEN"
city3 = "HASSELT"
city4 = "GENT"
City =  Vastgoed.query(f'lokaliteit == "{city}"')
City2 = Vastgoed.query(f'lokaliteit == "{city2}"')
City3 = Vastgoed.query(f'lokaliteit == "{city3}"')
City4 = Vastgoed.query(f'lokaliteit == "{city4}"')

# City Periods
City_q1 = City.query('periode == "Q1"')[['mediaanHuizen', 'jaar']]
City_q2 = City.query('periode == "Q2"')[['mediaanAppartement', 'jaar']]

City2_q1 = City2.query('periode == "Q1"')[['mediaanHuizen', 'jaar']]
City2_q2 = City2.query('periode == "Q2"')[['mediaanAppartement', 'jaar']]

City3_q1 = City3.query('periode == "Q1"')[['mediaanHuizen', 'jaar']]
City3_q2 = City3.query('periode == "Q2"')[['mediaanAppartement', 'jaar']]

City4_q1 = City4.query('periode == "Q1"')[['mediaanHuizen', 'jaar']]
City4_q2 = City4.query('periode == "Q2"')[['mediaanAppartement', 'jaar']]


# City Median
City_q1_median = City_q1[['mediaanHuizen']]
City_q2_median = City_q2[['mediaanAppartement']]

City2_q1_median = City2_q1[['mediaanHuizen']]
City2_q2_median = City2_q2[['mediaanAppartement']]

City3_q1_median = City3_q1[['mediaanHuizen']]
City3_q2_median = City3_q2[['mediaanAppartement']]

City4_q1_median = City4_q1[['mediaanHuizen']]
City4_q2_median = City4_q2[['mediaanAppartement']]

# City Years
City_q1_jaar = City_q1[['jaar']]
City_q2_jaar = City_q2[['jaar']]
plt.plot(City_q1_jaar, City_q1_median, label="Huizen")
plt.plot(City_q2_jaar, City_q2_median, label="Appartementen")


plt.title(f'{city} House Prices')
plt.xlabel('Year')
plt.ylabel('Price')
plt.legend()
plt.show()

City2_q1_jaar = City2_q1[['jaar']]
City2_q2_jaar = City2_q2[['jaar']]
plt.plot(City2_q1_jaar, City2_q1_median, label="Huizen")
plt.plot(City2_q2_jaar, City2_q2_median, label="Appartementen")


plt.title(f'{city2} House Prices')
plt.xlabel('Year')
plt.ylabel('Price')
plt.legend()
plt.show()

City3_q1_jaar = City3_q1[['jaar']]
City3_q2_jaar = City3_q2[['jaar']]
plt.plot(City3_q1_jaar, City3_q1_median, label="Huizen")
plt.plot(City3_q2_jaar, City3_q2_median, label="Appartementen")


plt.title(f'{city3} House Prices')
plt.xlabel('Year')
plt.ylabel('Price')
plt.legend()
plt.show()

City4_q1_jaar = City4_q1[['jaar']]
City4_q2_jaar = City4_q2[['jaar']]
plt.plot(City4_q1_jaar, City4_q1_median, label="Huizen")
plt.plot(City4_q2_jaar, City4_q2_median, label="Appartementen")

plt.title(f'{city4} House Prices')
plt.xlabel('Year')
plt.ylabel('Price')
plt.legend()
plt.show()
